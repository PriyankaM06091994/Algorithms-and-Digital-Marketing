# %%
# !pip install Faker
# Out:
# ...
#      |████████████████████████████████| 1.0MB 3.3MB/s
# ...

# %%
import pandas as pd
from faker import Faker 
fake = Faker('')

# %%
import random

# %%
item = ['Kurkure', 'Hajmola', 'Dairy Milk', 'Krispy Karela', 'Kaju Katli',
                'Salted Peanuts', 'Bhakarwadi', 'Potato Chivda','Salted Chana',
         'Balaji Chips','Perk','Parle-G','Khakra',
        'Chakri','Meeri chips','Monaco','Dried Amla','Munch',
         'Fafda','Banana Chips','Bhel'
        'Haldiram chips','Kettle Chips','Milanos','Starburst']
len(item)
# Out:
# 24

# %%
itemID = ['101','102','103','104','105','106','107','108','109','110','111','112','113','114','115','116','117','118','119','120','121','122','123','124']

# %%
snack_weight=['25 gm','30 gm','20 gm','25 gm','40 gm','45 gm','40 gm','20 gm','10 gm','20 gm','30 gm','50 gm','60 gm','40 gm','25 gm','35 gm','35 gm','20 gm','20 gm','70 gm','10 gm','30 gm','25 gm','10 gm']

# %%
snack_rate=['$ 2.00','$ 2.00','$ 2.00','$ 2.00','$ 2.00','$ 2.00','$ 2.00','$ 1.99','$ 2.99','$ 2.49','$ 2.99','$ 2.49','$ 2.99','$ 2.99','$ 4.99','$ 3.49','$ 2.89','$ 2.49','$ 3.99','$ 2.79','$ 2.29','$ 2.49','$ 2.99','$ 3.00',]

# %%
snack_comp = list(zip(itemID,item,snack_weight,snack_rate))
snack_comp_1 = list(zip(itemID,item,snack_weight,snack_rate))
snack_comp = pd.DataFrame(snack_comp, columns =('itemID',' item', 'Weight', 'Rate'))
snack_comp
# Out:
#    itemID                item Weight    Rate
# 0     101             Kurkure  25 gm  $ 2.00
# 1     102             Hajmola  30 gm  $ 2.00
# 2     103          Dairy Milk  20 gm  $ 2.00
# 3     104       Krispy Karela  25 gm  $ 2.00
# 4     105          Kaju Katli  40 gm  $ 2.00
# 5     106      Salted Peanuts  45 gm  $ 2.00
# 6     107          Bhakarwadi  40 gm  $ 2.00
# 7     108       Potato Chivda  20 gm  $ 1.99
# 8     109        Salted Chana  10 gm  $ 2.99
# 9     110        Balaji Chips  20 gm  $ 2.49
# 10    111                Perk  30 gm  $ 2.99
# 11    112             Parle-G  50 gm  $ 2.49
# 12    113              Khakra  60 gm  $ 2.99
# 13    114              Chakri  40 gm  $ 2.99
# 14    115         Meeri chips  25 gm  $ 4.99
# 15    116              Monaco  35 gm  $ 3.49
# 16    117          Dried Amla  35 gm  $ 2.89
# 17    118               Munch  20 gm  $ 2.49
# 18    119               Fafda  20 gm  $ 3.99
# 19    120        Banana Chips  70 gm  $ 2.79
# ...

# %%
snack_comp['itemID'] = snack_comp['itemID'].astype(str).astype(int)
snack_comp['itemID']
# Out:
# 0     101
# 1     102
# 2     103
# 3     104
# 4     105
# 5     106
# 6     107
# 7     108
# 8     109
# 9     110
# 10    111
# 11    112
# 12    113
# 13    114
# 14    115
# 15    116
# 16    117
# 17    118
# 18    119
# 19    120
# 20    121
# 21    122
# 22    123
# 23    124
# Name: itemID, dtype: int64

# %%
def user_id_gen(how_many):
  userID = []
  for _ in range(0,how_many):
    userID.append(random.randint(500001,500500))
  return userID

# %%
userID = []
for i in user_id_gen(5000):
    userID.append(i)
len(userID)
# Out:
# 5000

# %%
x = len(userID)
x
# Out:
# 5000

# %%
def snack_dataset(how_many):
  s_all = []
  for _ in range(0,how_many):
    s_all.append(random.choice(snack_comp_1))
  return s_all

# %%
s_name = []
for i in snack_dataset(5000):
    s_name.append(i)
len(s_name)
# Out:
# 5000

# %%
snack_complete = pd.DataFrame(s_name, columns =('itemID','item', 'Weight', 'Rate'))
snack_complete['userID'] = userID
snack_complete['itemID']
# Out:
# 0       107
# 1       109
# 2       103
# 3       106
# 4       118
#        ...
# 4995    116
# 4996    122
# 4997    110
# 4998    107
# 4999    118
# Name: itemID, Length: 5000, dtype: object

# %%
snack_complete['itemID'] = snack_complete['itemID'].astype(str).astype(int)
snack_complete['itemID']
# Out:
# 0       107
# 1       109
# 2       103
# 3       106
# 4       118
#        ...
# 4995    116
# 4996    122
# 4997    110
# 4998    107
# 4999    118
# Name: itemID, Length: 5000, dtype: int64

# %%
def review_generate(how_many):
  rating = []
  for _ in range(0,how_many):
    rating.append(random.randint(0,5))
  return rating

# %%
rating = []
for i in review_generate(5000):
    rating.append(i)
rating
snack_complete['rating'] = rating
snack_complete
# Out:
#       itemID            item Weight    Rate  userID  rating
# 0        107      Bhakarwadi  40 gm  $ 2.00  500477       1
# 1        109    Salted Chana  10 gm  $ 2.99  500108       3
# 2        103      Dairy Milk  20 gm  $ 2.00  500347       1
# 3        106  Salted Peanuts  45 gm  $ 2.00  500307       2
# 4        118           Munch  20 gm  $ 2.49  500287       3
# ...      ...             ...    ...     ...     ...     ...
# 4995     116          Monaco  35 gm  $ 3.49  500261       1
# 4996     122    Kettle Chips  30 gm  $ 2.49  500185       2
# 4997     110    Balaji Chips  20 gm  $ 2.49  500436       0
# 4998     107      Bhakarwadi  40 gm  $ 2.00  500224       0
# 4999     118           Munch  20 gm  $ 2.49  500168       0
#
# [5000 rows x 6 columns]

# %%
df = snack_complete[['userID','itemID','rating']]

# %% [markdown]
# **Model**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/recommenders
# Out:
# /content/drive/My Drive/recommenders

# %%
pip install surprise
# Out:
# ...
#      |████████████████████████████████| 11.8MB 342kB/s
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp36-cp36m-linux_x86_64.whl size=1670938 sha256=311112413204b0d148226f30ea4258e561523a4cbdce59b18c360c45126032bf
#   Stored in directory: /root/.cache/pip/wheels/78/9c/3d/41b419c9d2aff5b6e2b4c0fc8d25c538202834058f9ed110d0
# Successfully built scikit-surprise
# ...

# %%
pip install papermill
# Out:
# ...
#      |████████████████████████████████| 71kB 3.4MB/s
# ...
#      |████████████████████████████████| 102kB 8.3MB/s
# ...
#      |████████████████████████████████| 747kB 34.1MB/s
# ...
# ERROR: nbclient 0.4.1 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# ...

# %%
import sys
sys.path.append("../../")
import os
import surprise
import papermill as pm
import pandas as pd
import numpy as np

from reco_utils.common.timer import Timer
from reco_utils.dataset import movielens
from reco_utils.dataset.python_splitters import python_random_split
from reco_utils.evaluation.python_evaluation import (rmse, mae, rsquared, exp_var, map_at_k, ndcg_at_k, precision_at_k, 
                                                     recall_at_k, get_top_k_items)
from reco_utils.recommender.surprise.surprise_utils import predict, compute_ranking_predictions

print("System version: {}".format(sys.version))
print("Surprise version: {}".format(surprise.__version__))
# Out:
# System version: 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0]
# Surprise version: 1.1.1

# %%
df['rating']
# Out:
# 0       1
# 1       3
# 2       1
# 3       2
# 4       3
#        ..
# 4995    1
# 4996    2
# 4997    0
# 4998    0
# 4999    0
# Name: rating, Length: 5000, dtype: int64

# %%
train, test = python_random_split(df, 0.75)

# %%
test.head(10)
# Out:
#       userID  itemID  rating
# 1501  500075     109       5
# 2586  500139     114       0
# 2653  500478     117       4
# 1055  500241     116       3
# 705   500297     124       3
# 106   500424     114       1
# 589   500270     104       0
# 2468  500026     119       4
# 2413  500279     121       5
# 1600  500190     106       1

# %%
from surprise import Dataset
from surprise import Reader

# %%
reader = Reader(rating_scale=(1, 5))

# %%
train_set = Dataset.load_from_df(train, reader).build_full_trainset()
train_set

# %%
svd = surprise.SVD(random_state=0, n_factors=200, n_epochs=30, verbose=True)

# %%
with Timer() as train_time:
    svd.fit(train_set)

print("Took {} seconds for training.".format(train_time.interval))
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Took 0.6102394229999959 seconds for training.

# %%
import pickle

# %%
pickle.dump( svd, open( "tr1.p", "wb" ) )

# %%
svd = pickle.load( open( "tr1.p", "rb" ) )

# %%
with Timer() as t:
    all_predictions = compute_ranking_predictions(svd, train, usercol='userID', itemcol='itemID', remove_seen=True)
print("Took {} seconds for prediction.".format(t))
# Out:
# Took 0.1849 seconds for prediction.

# %%
print(all_predictions)
# Out:
#        userID  itemID  prediction
# 3750   500314     113    2.001656
# 3751   500314     110    2.577766
# 3752   500314     111    2.241881
# 3753   500314     123    2.156203
# 3754   500314     101    2.947111
# ...       ...     ...         ...
# 12531  500210     102    2.592687
# 12532  500210     107    2.056029
# 12533  500210     118    2.641928
# 12534  500210     116    1.821993
# 12535  500210     120    2.056520
#
# [8786 rows x 3 columns]

# %%
k = 10
eval_map = map_at_k(test, all_predictions, col_prediction='prediction', k=k)
eval_ndcg = ndcg_at_k(test, all_predictions, col_prediction='prediction', k=k)
eval_precision = precision_at_k(test, all_predictions, col_prediction='prediction', k=k)
eval_recall = recall_at_k(test, all_predictions, col_prediction='prediction', k=k)

# %% [markdown]
# test

# %%
user = input("Enter User ID")
item = input("Enter Item ID ")

df1 = pd.DataFrame(data={
    "userID":[int(user)],
    "itemID":[int(item)]
})
# Out:
# Enter User ID500075
# Enter Item ID 101

# %%
with Timer() as t:
   foo = compute_ranking_predictions(svd, df1, usercol='userID', itemcol='itemID', remove_seen=True)
print("Took {} seconds for prediction.".format(t))
# Out:
# Took 0.1759 seconds for prediction.

# %%
foo["userID"] = foo["userID"] .apply(lambda x :  round(x))
foo["itemID"] = foo["itemID"] .apply(lambda x :  round(x))

# %%
result = foo[foo["userID"]==int(user)].sort_values(by='prediction', ascending=False).head(10)
result = result.drop(columns=["prediction", "userID"], axis=1)

# %%
result.to_json()
# Out:
# '{"itemID":{"8087":116,"8083":121,"8078":119,"8074":115,"8088":120,"8081":108,"8085":102,"8084":106,"8086":107,"8076":117}}'
