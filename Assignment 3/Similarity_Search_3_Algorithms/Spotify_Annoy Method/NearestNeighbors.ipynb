# %%
# !pip install annoy
# Out:
# Collecting annoy
#   Downloading https://files.pythonhosted.org/packages/00/15/5a9db225ebda93a235aebd5e42bbf83ab7035e7e4783c6cb528c635c9afb/annoy-1.16.3.tar.gz (644kB)
#      |████████████████████████████████| 645kB 5.3MB/s
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.16.3-cp36-cp36m-linux_x86_64.whl size=297335 sha256=d5c900a6ee3c20e00bd87dd1c2ac1fe54426de3f70a6bd84d528b8c7570b191c
#   Stored in directory: /root/.cache/pip/wheels/f3/01/54/6ef760fe9f9fc6ba8c19cebbe6358212b5f3b5b0195c0b813f
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.16.3

# %%
#################################################
# This script reads image feature vectors from a folder
# and saves the image similarity scores in json file
# by Erdem Isbilen - December/2019
#################################################

#################################################
# Imports and function definitions
#################################################

# Numpy for loading image feature vectors from file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# json for storing data in json file
import json

# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial
#################################################

# %%
#################################################
# This function reads from 'image_data.json' file
# Looks for a specific 'filename' value
# Returns the product id when product image names are matched 
# So it is used to find product id based on the product image name
#################################################
def match_id(filename):
  with open("/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/fin.json") as json_file:
    
    for file in json_file:
        seen = json.loads(file)

        for line in seen:
          
          if filename==line['imageName']:
            
            print(line)
            return line['productId']
            break
#################################################

# %%
#################################################
# This function; 
# Reads all image feature vectores stored in /feature-vectors/*.npz
# Adds them all in Annoy Index
# Builds ANNOY index
# Calculates the nearest neighbors and image similarity metrics
# Stores image similarity scores with productID in a json file
#################################################
def cluster():

  start_time = time.time()
  
  print("---------------------------------")
  print ("Step.1 - ANNOY index generation - Started at %s" %time.ctime())
  print("---------------------------------")

# %%
# Defining data structures as empty dict
file_index_to_file_name = {}
file_index_to_file_vector = {}
file_index_to_product_id = {}

# %%
  # Configuring annoy parameters
  dims = 1792
  n_nearest_neighbors = 20
  trees = 10000

# %%
  # Reads all file names which stores feature vectors 
  allfiles = glob.glob('/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/*.npz')

# %%
t = AnnoyIndex(dims, metric='angular')

# %%
for file_index, i in enumerate(allfiles):
    
    start_time = time.time()
    # Reads feature vectors and assigns them into the file_vector 
    file_vector = np.loadtxt(i)

    # Assigns file_name, feature_vectors and corresponding product_id
    file_name = os.path.basename(i).split('.')[0]
    file_index_to_file_name[file_index] = file_name
    file_index_to_file_vector[file_index] = file_vector
    file_index_to_product_id[file_index] = match_id(file_name)

    # Adds image feature vectors into annoy index   
    t.add_item(file_index, file_vector)

    print("---------------------------------")
    print("Annoy index     : %s" %file_index)
    print("Image file name : %s" %file_name)
    print("Product id      : %s" %file_index_to_product_id[file_index])
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

# %%
  # Builds annoy index
  t.build(trees)

  print ("Step.1 - ANNOY index generation - Finished")
  print ("Step.2 - Similarity score calculation - Started ") 
  
  named_nearest_neighbors = []

  # Loops through all indexed items
  for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
    master_file_name = file_index_to_file_name[i]
    master_vector = file_index_to_file_vector[i]
    master_product_id = file_index_to_product_id[i]

    # Calculates the nearest neighbors of the master item
    nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

    # Loops through the nearest neighbors of the master item
    for j in nearest_neighbors:

      print(j)

      # Assigns file_name, image feature vectors and product id values of the similar item
      neighbor_file_name = file_index_to_file_name[j]
      neighbor_file_vector = file_index_to_file_vector[j]
      neighbor_product_id = file_index_to_product_id[j]

      # Calculates the similarity score of the similar item
      similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
      rounded_similarity = int((similarity * 10000)) / 10000.0

      # Appends master product id with the similarity score 
      # and the product id of the similar items
      named_nearest_neighbors.append({
        'similarity': rounded_similarity,
        'master_pi': master_product_id,
        'similar_pi': neighbor_product_id})

    print("---------------------------------") 
    print("Similarity index       : %s" %i)
    print("Master Image file name : %s" %file_index_to_file_name[i]) 
    print("Nearest Neighbors.     : %s" %nearest_neighbors) 
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  
  print ("Step.2 - Similarity score calculation - Finished ") 

  # Writes the 'named_nearest_neighbors' to a json file
  with open('nearest_neighbors.json', 'w') as out:
    json.dump(named_nearest_neighbors, out)

  print ("Step.3 - Data stored in 'nearest_neighbors.json' file ") 
  print("--- Prosess completed in %.2f minutes ---------" % ((time.time() - start_time)/60))

cluster()
# Out:
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# 0
# 84
# 87
# 40
# 75
# 17
# 22
# 26
# 54
# 60
# 47
# 56
# 96
# 18
# 1
# 104
# 86
# 102
# 31
# 27
# ---------------------------------
# Similarity index       : 0
# Master Image file name : 0_0
# Nearest Neighbors.     : [0, 84, 87, 40, 75, 17, 22, 26, 54, 60, 47, 56, 96, 18, 1, 104, 86, 102, 31, 27]
# --- 0.78 minutes passed ---------
# 1
# 87
# 95
# 84
# 75
# 102
# 0
# 96
# 47
# 36
# 14
# 41
# 26
# 22
# 18
# 109
# 100
# 107
# 54
# 60
# ---------------------------------
# Similarity index       : 1
# Master Image file name : 48_0
# Nearest Neighbors.     : [1, 87, 95, 84, 75, 102, 0, 96, 47, 36, 14, 41, 26, 22, 18, 109, 100, 107, 54, 60]
# --- 0.78 minutes passed ---------
# 2
# 6
# 31
# 86
# 89
# 21
# 28
# 81
# 48
# 16
# 0
# 66
# 67
# 104
# 12
# 34
# 17
# 53
# 56
# 79
# ---------------------------------
# Similarity index       : 2
# Master Image file name : 43_1
# Nearest Neighbors.     : [2, 6, 31, 86, 89, 21, 28, 81, 48, 16, 0, 66, 67, 104, 12, 34, 17, 53, 56, 79]
# --- 0.78 minutes passed ---------
# 3
# 24
# 25
# 59
# 92
# 44
# 45
# 21
# 28
# 19
# 86
# 71
# 93
# 97
# 69
# 14
# 18
# 31
# 48
# 75
# ---------------------------------
# Similarity index       : 3
# Master Image file name : 46_0
# Nearest Neighbors.     : [3, 24, 25, 59, 92, 44, 45, 21, 28, 19, 86, 71, 93, 97, 69, 14, 18, 31, 48, 75]
# --- 0.78 minutes passed ---------
# 4
# 9
# 60
# 15
# 11
# 102
# 27
# 73
# 64
# 38
# 107
# 109
# 20
# 14
# 18
# 23
# 62
# 47
# 70
# 104
# ---------------------------------
# Similarity index       : 4
# Master Image file name : 44_0
# Nearest Neighbors.     : [4, 9, 60, 15, 11, 102, 27, 73, 64, 38, 107, 109, 20, 14, 18, 23, 62, 47, 70, 104]
# --- 0.78 minutes passed ---------
# 5
# 65
# 45
# 78
# 71
# 44
# 48
# 101
# 58
# 81
# 57
# 97
# 68
# 2
# 49
# 6
# 3
# 31
# 0
# 21
# ---------------------------------
# Similarity index       : 5
# Master Image file name : 45_0
# Nearest Neighbors.     : [5, 65, 45, 78, 71, 44, 48, 101, 58, 81, 57, 97, 68, 2, 49, 6, 3, 31, 0, 21]
# --- 0.78 minutes passed ---------
# 6
# 2
# 31
# 86
# 16
# 21
# 28
# 12
# 10
# 34
# 89
# 66
# 81
# 48
# 67
# 101
# 0
# 93
# 104
# 79
# ---------------------------------
# Similarity index       : 6
# Master Image file name : 43_0
# Nearest Neighbors.     : [6, 2, 31, 86, 16, 21, 28, 12, 10, 34, 89, 66, 81, 48, 67, 101, 0, 93, 104, 79]
# --- 0.78 minutes passed ---------
# 7
# 104
# 33
# 50
# 51
# 106
# 20
# 11
# 109
# 54
# 29
# 107
# 70
# 23
# 9
# 14
# 75
# 64
# 108
# 18
# ---------------------------------
# Similarity index       : 7
# Master Image file name : 42_0
# Nearest Neighbors.     : [7, 104, 33, 50, 51, 106, 20, 11, 109, 54, 29, 107, 70, 23, 9, 14, 75, 64, 108, 18]
# --- 0.78 minutes passed ---------
# 8
# 19
# 18
# 39
# 21
# 28
# 23
# 59
# 93
# 11
# 14
# 36
# 35
# 62
# 102
# 0
# 22
# 94
# 4
# 63
# ---------------------------------
# Similarity index       : 8
# Master Image file name : 42_1
# Nearest Neighbors.     : [8, 19, 18, 39, 21, 28, 23, 59, 93, 11, 14, 36, 35, 62, 102, 0, 22, 94, 4, 63]
# --- 0.78 minutes passed ---------
# 9
# 11
# 4
# 29
# 64
# 20
# 18
# 33
# 47
# 60
# 50
# 102
# 107
# 46
# 73
# 38
# 14
# 26
# 91
# 32
# ---------------------------------
# Similarity index       : 9
# Master Image file name : 47_0
# Nearest Neighbors.     : [9, 11, 4, 29, 64, 20, 18, 33, 47, 60, 50, 102, 107, 46, 73, 38, 14, 26, 91, 32]
# --- 0.79 minutes passed ---------
# 10
# 12
# 82
# 16
# 21
# 28
# 34
# 6
# 86
# 66
# 43
# 2
# 93
# 31
# 48
# 59
# 45
# 52
# 19
# 35
# ---------------------------------
# Similarity index       : 10
# Master Image file name : 43_2
# Nearest Neighbors.     : [10, 12, 82, 16, 21, 28, 34, 6, 86, 66, 43, 2, 93, 31, 48, 59, 45, 52, 19, 35]
# --- 0.79 minutes passed ---------
# 11
# 9
# 109
# 107
# 4
# 73
# 47
# 18
# 20
# 29
# 14
# 64
# 74
# 75
# 102
# 60
# 91
# 62
# 26
# 38
# ---------------------------------
# Similarity index       : 11
# Master Image file name : 41_0
# Nearest Neighbors.     : [11, 9, 109, 107, 4, 73, 47, 18, 20, 29, 14, 64, 74, 75, 102, 60, 91, 62, 26, 38]
# --- 0.79 minutes passed ---------
# 12
# 16
# 10
# 21
# 28
# 66
# 31
# 6
# 56
# 86
# 51
# 67
# 82
# 2
# 108
# 104
# 93
# 43
# 101
# 0
# ---------------------------------
# Similarity index       : 12
# Master Image file name : 39_1
# Nearest Neighbors.     : [12, 16, 10, 21, 28, 66, 31, 6, 56, 86, 51, 67, 82, 2, 108, 104, 93, 43, 101, 0]
# --- 0.79 minutes passed ---------
# 13
# 105
# 61
# 85
# 50
# 106
# 103
# 104
# 56
# 55
# 29
# 51
# 83
# 54
# 62
# 46
# 60
# 27
# 23
# 4
# ---------------------------------
# Similarity index       : 13
# Master Image file name : 35_0
# Nearest Neighbors.     : [13, 105, 61, 85, 50, 106, 103, 104, 56, 55, 29, 51, 83, 54, 62, 46, 60, 27, 23, 4]
# --- 0.79 minutes passed ---------
# 14
# 107
# 18
# 102
# 96
# 109
# 87
# 11
# 4
# 74
# 26
# 20
# 88
# 9
# 64
# 1
# 19
# 60
# 47
# 38
# ---------------------------------
# Similarity index       : 14
# Master Image file name : 38_0
# Nearest Neighbors.     : [14, 107, 18, 102, 96, 109, 87, 11, 4, 74, 26, 20, 88, 9, 64, 1, 19, 60, 47, 38]
# --- 0.79 minutes passed ---------
# 15
# 4
# 88
# 20
# 60
# 74
# 103
# 64
# 96
# 11
# 26
# 102
# 23
# 56
# 107
# 73
# 9
# 27
# 47
# 18
# ---------------------------------
# Similarity index       : 15
# Master Image file name : 36_0
# Nearest Neighbors.     : [15, 4, 88, 20, 60, 74, 103, 64, 96, 11, 26, 102, 23, 56, 107, 73, 9, 27, 47, 18]
# --- 0.79 minutes passed ---------
# 16
# 12
# 10
# 21
# 28
# 6
# 66
# 31
# 56
# 2
# 86
# 67
# 93
# 82
# 51
# 108
# 101
# 43
# 81
# 104
# ---------------------------------
# Similarity index       : 16
# Master Image file name : 39_0
# Nearest Neighbors.     : [16, 12, 10, 21, 28, 6, 66, 31, 56, 2, 86, 67, 93, 82, 51, 108, 101, 43, 81, 104]
# --- 0.79 minutes passed ---------
# 17
# 0
# 54
# 95
# 84
# 2
# 87
# 40
# 100
# 36
# 104
# 32
# 22
# 6
# 50
# 33
# 77
# 60
# 75
# 26
# ---------------------------------
# Similarity index       : 17
# Master Image file name : 37_0
# Nearest Neighbors.     : [17, 0, 54, 95, 84, 2, 87, 40, 100, 36, 104, 32, 22, 6, 50, 33, 77, 60, 75, 26]
# --- 0.79 minutes passed ---------
# 18
# 102
# 14
# 107
# 26
# 11
# 62
# 9
# 47
# 4
# 22
# 87
# 0
# 64
# 19
# 96
# 109
# 73
# 60
# 74
# ---------------------------------
# Similarity index       : 18
# Master Image file name : 34_0
# Nearest Neighbors.     : [18, 102, 14, 107, 26, 11, 62, 9, 47, 4, 22, 87, 0, 64, 19, 96, 109, 73, 60, 74]
# --- 0.79 minutes passed ---------
# 19
# 86
# 18
# 22
# 14
# 21
# 28
# 59
# 9
# 87
# 33
# 102
# 52
# 96
# 0
# 108
# 66
# 51
# 69
# 34
# ---------------------------------
# Similarity index       : 19
# Master Image file name : 3_0
# Nearest Neighbors.     : [19, 86, 18, 22, 14, 21, 28, 59, 9, 87, 33, 102, 52, 96, 0, 108, 66, 51, 69, 34]
# --- 0.79 minutes passed ---------
# 20
# 38
# 64
# 11
# 46
# 9
# 15
# 4
# 29
# 33
# 109
# 14
# 32
# 74
# 73
# 23
# 106
# 90
# 39
# 50
# ---------------------------------
# Similarity index       : 20
# Master Image file name : 40_0
# Nearest Neighbors.     : [20, 38, 64, 11, 46, 9, 15, 4, 29, 33, 109, 14, 32, 74, 73, 23, 106, 90, 39, 50]
# --- 0.79 minutes passed ---------
# 21
# 28
# 12
# 16
# 86
# 31
# 6
# 10
# 2
# 93
# 66
# 19
# 108
# 51
# 81
# 67
# 27
# 34
# 35
# 56
# ---------------------------------
# Similarity index       : 21
# Master Image file name : 33_1
# Nearest Neighbors.     : [21, 28, 12, 16, 86, 31, 6, 10, 2, 93, 66, 19, 108, 51, 81, 67, 27, 34, 35, 56]
# --- 0.79 minutes passed ---------
# 22
# 87
# 0
# 96
# 84
# 18
# 26
# 19
# 59
# 39
# 36
# 32
# 51
# 1
# 95
# 108
# 33
# 107
# 76
# 75
# ---------------------------------
# Similarity index       : 22
# Master Image file name : 28_0
# Nearest Neighbors.     : [22, 87, 0, 96, 84, 18, 26, 19, 59, 39, 36, 32, 51, 1, 95, 108, 33, 107, 76, 75]
# --- 0.79 minutes passed ---------
# 23
# 106
# 4
# 54
# 73
# 20
# 50
# 15
# 32
# 9
# 51
# 104
# 70
# 11
# 107
# 33
# 14
# 84
# 60
# 56
# ---------------------------------
# Similarity index       : 23
# Master Image file name : 26_1
# Nearest Neighbors.     : [23, 106, 4, 54, 73, 20, 50, 15, 32, 9, 51, 104, 70, 11, 107, 33, 14, 84, 60, 56]
# --- 0.79 minutes passed ---------
# 24
# 25
# 92
# 3
# 21
# 28
# 19
# 59
# 86
# 44
# 52
# 22
# 34
# 97
# 69
# 66
# 48
# 39
# 51
# 93
# ---------------------------------
# Similarity index       : 24
# Master Image file name : 26_2
# Nearest Neighbors.     : [24, 25, 92, 3, 21, 28, 19, 59, 86, 44, 52, 22, 34, 97, 69, 66, 48, 39, 51, 93]
# --- 0.79 minutes passed ---------
# 25
# 24
# 92
# 3
# 59
# 21
# 28
# 19
# 86
# 39
# 34
# 93
# 35
# 22
# 66
# 12
# 32
# 10
# 16
# 51
# ---------------------------------
# Similarity index       : 25
# Master Image file name : 26_0
# Nearest Neighbors.     : [25, 24, 92, 3, 59, 21, 28, 19, 86, 39, 34, 93, 35, 22, 66, 12, 32, 10, 16, 51]
# --- 0.79 minutes passed ---------
# 26
# 87
# 84
# 102
# 18
# 60
# 47
# 96
# 0
# 74
# 64
# 14
# 88
# 11
# 107
# 22
# 9
# 15
# 76
# 33
# ---------------------------------
# Similarity index       : 26
# Master Image file name : 30_0
# Nearest Neighbors.     : [26, 87, 84, 102, 18, 60, 47, 96, 0, 74, 64, 14, 88, 11, 107, 22, 9, 15, 76, 33]
# --- 0.79 minutes passed ---------
# 27
# 104
# 4
# 102
# 51
# 56
# 60
# 108
# 0
# 31
# 26
# 15
# 64
# 21
# 28
# 47
# 9
# 35
# 33
# 88
# ---------------------------------
# Similarity index       : 27
# Master Image file name : 2_0
# Nearest Neighbors.     : [27, 104, 4, 102, 51, 56, 60, 108, 0, 31, 26, 15, 64, 21, 28, 47, 9, 35, 33, 88]
# --- 0.79 minutes passed ---------
# 21
# 28
# 12
# 16
# 86
# 31
# 6
# 10
# 2
# 93
# 66
# 19
# 108
# 51
# 81
# 67
# 27
# 34
# 35
# 56
# ---------------------------------
# Similarity index       : 28
# Master Image file name : 33_0
# Nearest Neighbors.     : [21, 28, 12, 16, 86, 31, 6, 10, 2, 93, 66, 19, 108, 51, 81, 67, 27, 34, 35, 56]
# --- 0.79 minutes passed ---------
# 29
# 46
# 9
# 50
# 11
# 20
# 91
# 4
# 109
# 105
# 64
# 73
# 70
# 33
# 18
# 107
# 60
# 62
# 7
# 38
# ---------------------------------
# Similarity index       : 29
# Master Image file name : 31_0
# Nearest Neighbors.     : [29, 46, 9, 50, 11, 20, 91, 4, 109, 105, 64, 73, 70, 33, 18, 107, 60, 62, 7, 38]
# --- 0.79 minutes passed ---------
# 30
# 66
# 6
# 2
# 86
# 16
# 19
# 12
# 108
# 21
# 28
# 51
# 34
# 79
# 31
# 96
# 27
# 35
# 53
# 81
# ---------------------------------
# Similarity index       : 30
# Master Image file name : 26_3
# Nearest Neighbors.     : [30, 66, 6, 2, 86, 16, 19, 12, 108, 21, 28, 51, 34, 79, 31, 96, 27, 35, 53, 81]
# --- 0.79 minutes passed ---------
# 31
# 67
# 51
# 56
# 104
# 2
# 86
# 108
# 6
# 96
# 21
# 28
# 101
# 103
# 66
# 45
# 0
# 16
# 12
# 27
# ---------------------------------
# Similarity index       : 31
# Master Image file name : 25_3
# Nearest Neighbors.     : [31, 67, 51, 56, 104, 2, 86, 108, 6, 96, 21, 28, 101, 103, 66, 45, 0, 16, 12, 27]
# --- 0.79 minutes passed ---------
# 32
# 39
# 38
# 33
# 20
# 50
# 54
# 22
# 9
# 23
# 4
# 18
# 36
# 100
# 104
# 15
# 95
# 0
# 102
# 84
# ---------------------------------
# Similarity index       : 32
# Master Image file name : 25_0
# Nearest Neighbors.     : [32, 39, 38, 33, 20, 50, 54, 22, 9, 23, 4, 18, 36, 100, 104, 15, 95, 0, 102, 84]
# --- 0.79 minutes passed ---------
# 33
# 50
# 9
# 84
# 32
# 20
# 104
# 64
# 7
# 87
# 54
# 108
# 39
# 26
# 11
# 0
# 29
# 22
# 96
# 23
# ---------------------------------
# Similarity index       : 33
# Master Image file name : 19_1
# Nearest Neighbors.     : [33, 50, 9, 84, 32, 20, 104, 64, 7, 87, 54, 108, 39, 26, 11, 0, 29, 22, 96, 23]
# --- 0.79 minutes passed ---------
# 34
# 86
# 66
# 10
# 6
# 59
# 21
# 28
# 2
# 19
# 48
# 31
# 35
# 92
# 108
# 16
# 12
# 45
# 0
# 22
# ---------------------------------
# Similarity index       : 34
# Master Image file name : 22_0
# Nearest Neighbors.     : [34, 86, 66, 10, 6, 59, 21, 28, 2, 19, 48, 31, 35, 92, 108, 16, 12, 45, 0, 22]
# --- 0.79 minutes passed ---------
# 35
# 51
# 27
# 21
# 28
# 66
# 86
# 102
# 74
# 108
# 4
# 34
# 15
# 12
# 39
# 93
# 19
# 23
# 33
# 59
# ---------------------------------
# Similarity index       : 35
# Master Image file name : 19_0
# Nearest Neighbors.     : [35, 51, 27, 21, 28, 66, 86, 102, 74, 108, 4, 34, 15, 12, 39, 93, 19, 23, 33, 59]
# --- 0.79 minutes passed ---------
# 36
# 95
# 94
# 1
# 22
# 18
# 39
# 32
# 0
# 87
# 26
# 23
# 75
# 17
# 84
# 99
# 96
# 9
# 77
# 11
# ---------------------------------
# Similarity index       : 36
# Master Image file name : 20_0
# Nearest Neighbors.     : [36, 95, 94, 1, 22, 18, 39, 32, 0, 87, 26, 23, 75, 17, 84, 99, 96, 9, 77, 11]
# --- 0.79 minutes passed ---------
# 37
# 56
# 103
# 96
# 31
# 60
# 47
# 64
# 88
# 84
# 27
# 104
# 15
# 0
# 87
# 26
# 67
# 51
# 74
# 109
# ---------------------------------
# Similarity index       : 37
# Master Image file name : 18_0
# Nearest Neighbors.     : [37, 56, 103, 96, 31, 60, 47, 64, 88, 84, 27, 104, 15, 0, 87, 26, 67, 51, 74, 109]
# --- 0.79 minutes passed ---------
# 38
# 20
# 73
# 4
# 32
# 107
# 9
# 39
# 64
# 11
# 14
# 102
# 74
# 18
# 29
# 62
# 23
# 106
# 46
# 109
# ---------------------------------
# Similarity index       : 38
# Master Image file name : 25_1
# Nearest Neighbors.     : [38, 20, 73, 4, 32, 107, 9, 39, 64, 11, 14, 102, 74, 18, 29, 62, 23, 106, 46, 109]
# --- 0.79 minutes passed ---------
# 39
# 32
# 38
# 22
# 20
# 33
# 36
# 75
# 23
# 9
# 73
# 59
# 18
# 95
# 50
# 4
# 90
# 11
# 54
# 102
# ---------------------------------
# Similarity index       : 39
# Master Image file name : 25_2
# Nearest Neighbors.     : [39, 32, 38, 22, 20, 33, 36, 75, 23, 9, 73, 59, 18, 95, 50, 4, 90, 11, 54, 102]
# --- 0.79 minutes passed ---------
# 40
# 84
# 0
# 87
# 76
# 77
# 26
# 96
# 54
# 95
# 85
# 104
# 60
# 50
# 33
# 22
# 17
# 47
# 57
# 103
# ---------------------------------
# Similarity index       : 40
# Master Image file name : 1_0
# Nearest Neighbors.     : [40, 84, 0, 87, 76, 77, 26, 96, 54, 95, 85, 104, 60, 50, 33, 22, 17, 47, 57, 103]
# --- 0.79 minutes passed ---------
# 41
# 95
# 87
# 84
# 1
# 76
# 96
# 85
# 75
# 0
# 104
# 40
# 54
# 109
# 47
# 22
# 26
# 69
# 70
# 51
# ---------------------------------
# Similarity index       : 41
# Master Image file name : 17_0
# Nearest Neighbors.     : [41, 95, 87, 84, 1, 76, 96, 85, 75, 0, 104, 40, 54, 109, 47, 22, 26, 69, 70, 51]
# --- 0.79 minutes passed ---------
# 42
# 103
# 61
# 47
# 55
# 56
# 60
# 31
# 80
# 37
# 70
# 64
# 104
# 106
# 88
# 51
# 85
# 107
# 109
# 72
# ---------------------------------
# Similarity index       : 42
# Master Image file name : 12_0
# Nearest Neighbors.     : [42, 103, 61, 47, 55, 56, 60, 31, 80, 37, 70, 64, 104, 106, 88, 51, 85, 107, 109, 72]
# --- 0.79 minutes passed ---------
# 43
# 82
# 10
# 12
# 16
# 6
# 2
# 66
# 89
# 21
# 28
# 34
# 79
# 93
# 86
# 81
# 22
# 108
# 19
# 31
# ---------------------------------
# Similarity index       : 43
# Master Image file name : 101_0
# Nearest Neighbors.     : [43, 82, 10, 12, 16, 6, 2, 66, 89, 21, 28, 34, 79, 93, 86, 81, 22, 108, 19, 31]
# --- 0.79 minutes passed ---------
# 44
# 48
# 5
# 101
# 45
# 3
# 71
# 49
# 97
# 57
# 81
# 21
# 28
# 75
# 96
# 59
# 104
# 58
# 69
# 0
# ---------------------------------
# Similarity index       : 44
# Master Image file name : 13_0
# Nearest Neighbors.     : [44, 48, 5, 101, 45, 3, 71, 49, 97, 57, 81, 21, 28, 75, 96, 59, 104, 58, 69, 0]
# --- 0.79 minutes passed ---------
# 45
# 48
# 5
# 101
# 71
# 31
# 44
# 3
# 57
# 86
# 21
# 28
# 65
# 67
# 58
# 2
# 103
# 81
# 6
# 34
# ---------------------------------
# Similarity index       : 45
# Master Image file name : 13_1
# Nearest Neighbors.     : [45, 48, 5, 101, 71, 31, 44, 3, 57, 86, 21, 28, 65, 67, 58, 2, 103, 81, 6, 34]
# --- 0.79 minutes passed ---------
# 46
# 29
# 20
# 109
# 105
# 64
# 9
# 61
# 11
# 91
# 4
# 70
# 104
# 73
# 50
# 102
# 60
# 88
# 38
# 107
# ---------------------------------
# Similarity index       : 46
# Master Image file name : 16_0
# Nearest Neighbors.     : [46, 29, 20, 109, 105, 64, 9, 61, 11, 91, 4, 70, 104, 73, 50, 102, 60, 88, 38, 107]
# --- 0.79 minutes passed ---------
# 47
# 102
# 60
# 26
# 64
# 107
# 11
# 88
# 18
# 9
# 74
# 0
# 87
# 84
# 4
# 75
# 72
# 96
# 1
# 103
# ---------------------------------
# Similarity index       : 47
# Master Image file name : 11_0
# Nearest Neighbors.     : [47, 102, 60, 26, 64, 107, 11, 88, 18, 9, 74, 0, 87, 84, 4, 75, 72, 96, 1, 103]
# --- 0.79 minutes passed ---------
# 48
# 45
# 101
# 44
# 58
# 2
# 31
# 6
# 86
# 81
# 5
# 66
# 71
# 21
# 28
# 49
# 108
# 104
# 34
# 67
# ---------------------------------
# Similarity index       : 48
# Master Image file name : 13_3
# Nearest Neighbors.     : [48, 45, 101, 44, 58, 2, 31, 6, 86, 81, 5, 66, 71, 21, 28, 49, 108, 104, 34, 67]
# --- 0.79 minutes passed ---------
# 49
# 48
# 44
# 2
# 81
# 82
# 6
# 21
# 28
# 58
# 69
# 5
# 10
# 86
# 97
# 78
# 66
# 19
# 52
# 65
# ---------------------------------
# Similarity index       : 49
# Master Image file name : 13_2
# Nearest Neighbors.     : [49, 48, 44, 2, 81, 82, 6, 21, 28, 58, 69, 5, 10, 86, 97, 78, 66, 19, 52, 65]
# --- 0.79 minutes passed ---------
# 50
# 33
# 54
# 29
# 104
# 9
# 32
# 7
# 106
# 23
# 20
# 4
# 64
# 84
# 60
# 46
# 26
# 11
# 87
# 90
# ---------------------------------
# Similarity index       : 50
# Master Image file name : 15_0
# Nearest Neighbors.     : [50, 33, 54, 29, 104, 9, 32, 7, 106, 23, 20, 4, 64, 84, 60, 46, 26, 11, 87, 90]
# --- 0.80 minutes passed ---------
# 51
# 104
# 108
# 56
# 31
# 66
# 103
# 96
# 106
# 27
# 54
# 86
# 7
# 64
# 107
# 102
# 87
# 22
# 23
# 67
# ---------------------------------
# Similarity index       : 51
# Master Image file name : 73_1
# Nearest Neighbors.     : [51, 104, 108, 56, 31, 66, 103, 96, 106, 27, 54, 86, 7, 64, 107, 102, 87, 22, 23, 67]
# --- 0.80 minutes passed ---------
# 52
# 19
# 69
# 86
# 21
# 28
# 59
# 2
# 24
# 66
# 18
# 10
# 6
# 48
# 12
# 3
# 81
# 14
# 107
# 16
# ---------------------------------
# Similarity index       : 52
# Master Image file name : 71_0
# Nearest Neighbors.     : [52, 19, 69, 86, 21, 28, 59, 2, 24, 66, 18, 10, 6, 48, 12, 3, 81, 14, 107, 16]
# --- 0.80 minutes passed ---------
# 53
# 89
# 104
# 2
# 79
# 31
# 56
# 108
# 6
# 84
# 96
# 14
# 51
# 23
# 100
# 81
# 87
# 27
# 54
# 30
# ---------------------------------
# Similarity index       : 53
# Master Image file name : 64_2
# Nearest Neighbors.     : [53, 89, 104, 2, 79, 31, 56, 108, 6, 84, 96, 14, 51, 23, 100, 81, 87, 27, 54, 30]
# --- 0.80 minutes passed ---------
# 54
# 104
# 50
# 100
# 106
# 0
# 51
# 23
# 75
# 33
# 32
# 95
# 84
# 56
# 60
# 17
# 4
# 7
# 40
# 70
# ---------------------------------
# Similarity index       : 54
# Master Image file name : 64_1
# Nearest Neighbors.     : [54, 104, 50, 100, 106, 0, 51, 23, 75, 33, 32, 95, 84, 56, 60, 17, 4, 7, 40, 70]
# --- 0.80 minutes passed ---------
# 55
# 103
# 61
# 60
# 56
# 80
# 37
# 42
# 70
# 85
# 67
# 104
# 57
# 47
# 31
# 72
# 64
# 13
# 54
# 51
# ---------------------------------
# Similarity index       : 55
# Master Image file name : 70_0
# Nearest Neighbors.     : [55, 103, 61, 60, 56, 80, 37, 42, 70, 85, 67, 104, 57, 47, 31, 72, 64, 13, 54, 51]
# --- 0.80 minutes passed ---------
# 56
# 103
# 51
# 104
# 31
# 60
# 108
# 27
# 0
# 96
# 67
# 61
# 37
# 4
# 70
# 15
# 12
# 47
# 54
# 16
# ---------------------------------
# Similarity index       : 56
# Master Image file name : 73_0
# Nearest Neighbors.     : [56, 103, 51, 104, 31, 60, 108, 27, 0, 96, 67, 61, 37, 4, 70, 15, 12, 47, 54, 16]
# --- 0.80 minutes passed ---------
# 57
# 103
# 104
# 96
# 60
# 56
# 101
# 45
# 40
# 84
# 64
# 51
# 88
# 68
# 31
# 87
# 44
# 47
# 27
# 71
# ---------------------------------
# Similarity index       : 57
# Master Image file name : 72_0
# Nearest Neighbors.     : [57, 103, 104, 96, 60, 56, 101, 45, 40, 84, 64, 51, 88, 68, 31, 87, 44, 47, 27, 71]
# --- 0.80 minutes passed ---------
# 58
# 48
# 101
# 45
# 65
# 2
# 6
# 5
# 78
# 44
# 31
# 71
# 81
# 68
# 0
# 97
# 86
# 49
# 104
# 66
# ---------------------------------
# Similarity index       : 58
# Master Image file name : 6_0
# Nearest Neighbors.     : [58, 48, 101, 45, 65, 2, 6, 5, 78, 44, 31, 71, 81, 68, 0, 97, 86, 49, 104, 66]
# --- 0.80 minutes passed ---------
# 59
# 86
# 22
# 92
# 19
# 25
# 34
# 75
# 93
# 3
# 39
# 0
# 21
# 28
# 18
# 24
# 96
# 31
# 69
# 66
# ---------------------------------
# Similarity index       : 59
# Master Image file name : 69_0
# Nearest Neighbors.     : [59, 86, 22, 92, 19, 25, 34, 75, 93, 3, 39, 0, 21, 28, 18, 24, 96, 31, 69, 66]
# --- 0.80 minutes passed ---------
# 60
# 47
# 4
# 26
# 70
# 103
# 56
# 88
# 74
# 0
# 15
# 104
# 9
# 64
# 27
# 61
# 11
# 102
# 84
# 72
# ---------------------------------
# Similarity index       : 60
# Master Image file name : 66_0
# Nearest Neighbors.     : [60, 47, 4, 26, 70, 103, 56, 88, 74, 0, 15, 104, 9, 64, 27, 61, 11, 102, 84, 72]
# --- 0.80 minutes passed ---------
# 61
# 60
# 103
# 46
# 56
# 106
# 4
# 104
# 55
# 47
# 70
# 85
# 72
# 42
# 64
# 27
# 51
# 105
# 54
# 74
# ---------------------------------
# Similarity index       : 61
# Master Image file name : 64_0
# Nearest Neighbors.     : [61, 60, 103, 46, 56, 106, 4, 104, 55, 47, 70, 85, 72, 42, 64, 27, 51, 105, 54, 74]
# --- 0.80 minutes passed ---------
# 62
# 91
# 18
# 107
# 105
# 4
# 11
# 70
# 109
# 102
# 73
# 14
# 60
# 106
# 95
# 26
# 15
# 47
# 29
# 20
# ---------------------------------
# Similarity index       : 62
# Master Image file name : 60_0
# Nearest Neighbors.     : [62, 91, 18, 107, 105, 4, 11, 70, 109, 102, 73, 14, 60, 106, 95, 26, 15, 47, 29, 20]
# --- 0.80 minutes passed ---------
# 63
# 22
# 18
# 0
# 87
# 36
# 99
# 84
# 1
# 69
# 2
# 94
# 86
# 14
# 19
# 75
# 59
# 26
# 96
# 95
# ---------------------------------
# Similarity index       : 63
# Master Image file name : 5_0
# Nearest Neighbors.     : [63, 22, 18, 0, 87, 36, 99, 84, 1, 69, 2, 94, 86, 14, 19, 75, 59, 26, 96, 95]
# --- 0.80 minutes passed ---------
# 64
# 96
# 102
# 47
# 20
# 9
# 4
# 74
# 11
# 26
# 60
# 18
# 87
# 107
# 46
# 104
# 33
# 73
# 15
# 14
# ---------------------------------
# Similarity index       : 64
# Master Image file name : 61_0
# Nearest Neighbors.     : [64, 96, 102, 47, 20, 9, 4, 74, 11, 26, 60, 18, 87, 107, 46, 104, 33, 73, 15, 14]
# --- 0.80 minutes passed ---------
# 65
# 78
# 5
# 71
# 45
# 48
# 101
# 58
# 44
# 68
# 57
# 81
# 49
# 97
# 2
# 31
# 6
# 96
# 104
# 93
# ---------------------------------
# Similarity index       : 65
# Master Image file name : 57_1
# Nearest Neighbors.     : [65, 78, 5, 71, 45, 48, 101, 58, 44, 68, 57, 81, 49, 97, 2, 31, 6, 96, 104, 93]
# --- 0.80 minutes passed ---------
# 66
# 108
# 86
# 51
# 12
# 67
# 31
# 16
# 34
# 21
# 28
# 6
# 2
# 30
# 35
# 79
# 48
# 19
# 104
# 10
# ---------------------------------
# Similarity index       : 66
# Master Image file name : 62_1
# Nearest Neighbors.     : [66, 108, 86, 51, 12, 67, 31, 16, 34, 21, 28, 6, 2, 30, 35, 79, 48, 19, 104, 10]
# --- 0.80 minutes passed ---------
# 67
# 31
# 66
# 56
# 51
# 101
# 21
# 28
# 103
# 104
# 12
# 16
# 2
# 6
# 86
# 108
# 60
# 48
# 27
# 45
# ---------------------------------
# Similarity index       : 67
# Master Image file name : 62_0
# Nearest Neighbors.     : [67, 31, 66, 56, 51, 101, 21, 28, 103, 104, 12, 16, 2, 6, 86, 108, 60, 48, 27, 45]
# --- 0.80 minutes passed ---------
# 68
# 57
# 31
# 96
# 2
# 101
# 104
# 48
# 45
# 71
# 103
# 81
# 60
# 56
# 44
# 108
# 27
# 51
# 58
# 6
# ---------------------------------
# Similarity index       : 68
# Master Image file name : 58_0
# Nearest Neighbors.     : [68, 57, 31, 96, 2, 101, 104, 48, 45, 71, 103, 81, 60, 56, 44, 108, 27, 51, 58, 6]
# --- 0.80 minutes passed ---------
# 69
# 86
# 75
# 52
# 87
# 0
# 19
# 102
# 18
# 22
# 59
# 2
# 107
# 109
# 104
# 1
# 41
# 44
# 14
# 97
# ---------------------------------
# Similarity index       : 69
# Master Image file name : 59_0
# Nearest Neighbors.     : [69, 86, 75, 52, 87, 0, 19, 102, 18, 22, 59, 2, 107, 109, 104, 1, 41, 44, 14, 97]
# --- 0.80 minutes passed ---------
# 70
# 60
# 109
# 4
# 62
# 106
# 56
# 107
# 64
# 11
# 47
# 46
# 29
# 23
# 88
# 20
# 73
# 104
# 26
# 18
# ---------------------------------
# Similarity index       : 70
# Master Image file name : 63_0
# Nearest Neighbors.     : [70, 60, 109, 4, 62, 106, 56, 107, 64, 11, 47, 46, 29, 23, 88, 20, 73, 104, 26, 18]
# --- 0.80 minutes passed ---------
# 71
# 65
# 45
# 5
# 104
# 48
# 44
# 51
# 101
# 78
# 103
# 57
# 81
# 31
# 3
# 27
# 56
# 108
# 96
# 68
# ---------------------------------
# Similarity index       : 71
# Master Image file name : 57_2
# Nearest Neighbors.     : [71, 65, 45, 5, 104, 48, 44, 51, 101, 78, 103, 57, 81, 31, 3, 27, 56, 108, 96, 68]
# --- 0.80 minutes passed ---------
# 72
# 60
# 47
# 11
# 4
# 15
# 102
# 88
# 61
# 64
# 9
# 103
# 74
# 107
# 38
# 14
# 27
# 20
# 62
# 75
# ---------------------------------
# Similarity index       : 72
# Master Image file name : 4_0
# Nearest Neighbors.     : [72, 60, 47, 11, 4, 15, 102, 88, 61, 64, 9, 103, 74, 107, 38, 14, 27, 20, 62, 75]
# --- 0.80 minutes passed ---------
# 73
# 74
# 11
# 38
# 4
# 107
# 106
# 20
# 9
# 64
# 23
# 62
# 18
# 29
# 15
# 46
# 60
# 70
# 102
# 91
# ---------------------------------
# Similarity index       : 73
# Master Image file name : 52_0
# Nearest Neighbors.     : [73, 74, 11, 38, 4, 107, 106, 20, 9, 64, 23, 62, 18, 29, 15, 46, 60, 70, 102, 91]
# --- 0.80 minutes passed ---------
# 74
# 107
# 102
# 73
# 88
# 64
# 60
# 47
# 26
# 11
# 14
# 106
# 15
# 20
# 4
# 96
# 18
# 9
# 38
# 109
# ---------------------------------
# Similarity index       : 74
# Master Image file name : 51_0
# Nearest Neighbors.     : [74, 107, 102, 73, 88, 64, 60, 47, 26, 11, 14, 106, 15, 20, 4, 96, 18, 9, 38, 109]
# --- 0.80 minutes passed ---------
# 75
# 0
# 1
# 11
# 87
# 96
# 54
# 47
# 60
# 102
# 14
# 95
# 9
# 51
# 109
# 104
# 4
# 18
# 107
# 26
# ---------------------------------
# Similarity index       : 75
# Master Image file name : 53_0
# Nearest Neighbors.     : [75, 0, 1, 11, 87, 96, 54, 47, 60, 102, 14, 95, 9, 51, 109, 104, 4, 18, 107, 26]
# --- 0.80 minutes passed ---------
# 76
# 84
# 40
# 87
# 26
# 95
# 77
# 33
# 22
# 50
# 41
# 54
# 0
# 96
# 1
# 100
# 18
# 104
# 47
# 85
# ---------------------------------
# Similarity index       : 76
# Master Image file name : 55_0
# Nearest Neighbors.     : [76, 84, 40, 87, 26, 95, 77, 33, 22, 50, 41, 54, 0, 96, 1, 100, 18, 104, 47, 85]
# --- 0.80 minutes passed ---------
# 77
# 84
# 40
# 0
# 76
# 87
# 22
# 36
# 17
# 26
# 54
# 95
# 32
# 23
# 18
# 100
# 41
# 50
# 94
# 1
# ---------------------------------
# Similarity index       : 77
# Master Image file name : 56_0
# Nearest Neighbors.     : [77, 84, 40, 0, 76, 87, 22, 36, 17, 26, 54, 95, 32, 23, 18, 100, 41, 50, 94, 1]
# --- 0.80 minutes passed ---------
# 78
# 65
# 5
# 71
# 58
# 48
# 44
# 101
# 45
# 49
# 68
# 81
# 57
# 97
# 2
# 104
# 6
# 99
# 31
# 3
# ---------------------------------
# Similarity index       : 78
# Master Image file name : 57_0
# Nearest Neighbors.     : [78, 65, 5, 71, 58, 48, 44, 101, 45, 49, 68, 81, 57, 97, 2, 104, 6, 99, 31, 3]
# --- 0.80 minutes passed ---------
# 79
# 66
# 2
# 14
# 53
# 6
# 4
# 21
# 28
# 96
# 20
# 31
# 104
# 32
# 108
# 56
# 19
# 38
# 64
# 27
# ---------------------------------
# Similarity index       : 79
# Master Image file name : 54_0
# Nearest Neighbors.     : [79, 66, 2, 14, 53, 6, 4, 21, 28, 96, 20, 31, 104, 32, 108, 56, 19, 38, 64, 27]
# --- 0.80 minutes passed ---------
# 80
# 103
# 55
# 42
# 67
# 31
# 104
# 60
# 56
# 64
# 51
# 61
# 57
# 70
# 47
# 108
# 4
# 101
# 75
# 29
# ---------------------------------
# Similarity index       : 80
# Master Image file name : 50_0
# Nearest Neighbors.     : [80, 103, 55, 42, 67, 31, 104, 60, 56, 64, 51, 61, 57, 70, 47, 108, 4, 101, 75, 29]
# --- 0.80 minutes passed ---------
# 81
# 2
# 21
# 28
# 6
# 31
# 89
# 48
# 101
# 104
# 67
# 16
# 93
# 14
# 45
# 44
# 96
# 71
# 56
# 12
# ---------------------------------
# Similarity index       : 81
# Master Image file name : 97_1
# Nearest Neighbors.     : [81, 2, 21, 28, 6, 31, 89, 48, 101, 104, 67, 16, 93, 14, 45, 44, 96, 71, 56, 12]
# --- 0.80 minutes passed ---------
# 82
# 10
# 43
# 12
# 16
# 21
# 28
# 6
# 81
# 93
# 49
# 2
# 52
# 66
# 48
# 45
# 86
# 56
# 34
# 59
# ---------------------------------
# Similarity index       : 82
# Master Image file name : 97_0
# Nearest Neighbors.     : [82, 10, 43, 12, 16, 21, 28, 6, 81, 93, 49, 2, 52, 66, 48, 45, 86, 56, 34, 59]
# --- 0.80 minutes passed ---------
# 83
# 106
# 73
# 74
# 105
# 107
# 91
# 23
# 62
# 11
# 88
# 29
# 60
# 109
# 70
# 46
# 13
# 47
# 18
# 7
# ---------------------------------
# Similarity index       : 83
# Master Image file name : 9_0
# Nearest Neighbors.     : [83, 106, 73, 74, 105, 107, 91, 23, 62, 11, 88, 29, 60, 109, 70, 46, 13, 47, 18, 7]
# --- 0.80 minutes passed ---------
# 84
# 87
# 26
# 0
# 40
# 96
# 76
# 1
# 22
# 95
# 33
# 47
# 102
# 88
# 104
# 60
# 41
# 109
# 18
# 50
# ---------------------------------
# Similarity index       : 84
# Master Image file name : 98_1
# Nearest Neighbors.     : [84, 87, 26, 0, 40, 96, 76, 1, 22, 95, 33, 47, 102, 88, 104, 60, 41, 109, 18, 50]
# --- 0.80 minutes passed ---------
# 85
# 60
# 0
# 95
# 84
# 47
# 41
# 40
# 61
# 54
# 104
# 75
# 103
# 56
# 106
# 1
# 50
# 87
# 29
# 96
# ---------------------------------
# Similarity index       : 85
# Master Image file name : 99_0
# Nearest Neighbors.     : [85, 60, 0, 95, 84, 47, 41, 40, 61, 54, 104, 75, 103, 56, 106, 1, 50, 87, 29, 96]
# --- 0.80 minutes passed ---------
# 86
# 34
# 31
# 66
# 21
# 28
# 2
# 59
# 6
# 69
# 19
# 0
# 51
# 93
# 12
# 10
# 16
# 22
# 108
# 104
# ---------------------------------
# Similarity index       : 86
# Master Image file name : 95_0
# Nearest Neighbors.     : [86, 34, 31, 66, 21, 28, 2, 59, 6, 69, 19, 0, 51, 93, 12, 10, 16, 22, 108, 104]
# --- 0.80 minutes passed ---------
# 87
# 84
# 26
# 96
# 0
# 22
# 102
# 1
# 40
# 14
# 47
# 18
# 75
# 64
# 95
# 104
# 76
# 109
# 88
# 33
# ---------------------------------
# Similarity index       : 87
# Master Image file name : 98_2
# Nearest Neighbors.     : [87, 84, 26, 96, 0, 22, 102, 1, 40, 14, 47, 18, 75, 64, 95, 104, 76, 109, 88, 33]
# --- 0.80 minutes passed ---------
# 88
# 15
# 60
# 74
# 47
# 102
# 107
# 84
# 14
# 26
# 96
# 87
# 64
# 103
# 109
# 20
# 70
# 11
# 4
# 9
# ---------------------------------
# Similarity index       : 88
# Master Image file name : 98_0
# Nearest Neighbors.     : [88, 15, 60, 74, 47, 102, 107, 84, 14, 26, 96, 87, 64, 103, 109, 20, 70, 11, 4, 9]
# --- 0.81 minutes passed ---------
# 89
# 2
# 53
# 6
# 81
# 31
# 108
# 96
# 87
# 84
# 16
# 21
# 28
# 79
# 56
# 43
# 12
# 22
# 14
# 30
# ---------------------------------
# Similarity index       : 89
# Master Image file name : 98_3
# Nearest Neighbors.     : [89, 2, 53, 6, 81, 31, 108, 96, 87, 84, 16, 21, 28, 79, 56, 43, 12, 22, 14, 30]
# --- 0.81 minutes passed ---------
# 90
# 20
# 50
# 26
# 33
# 74
# 11
# 4
# 64
# 75
# 15
# 39
# 109
# 104
# 96
# 18
# 73
# 87
# 60
# 102
# ---------------------------------
# Similarity index       : 90
# Master Image file name : 92_0
# Nearest Neighbors.     : [90, 20, 50, 26, 33, 74, 11, 4, 64, 75, 15, 39, 109, 104, 96, 18, 73, 87, 60, 102]
# --- 0.81 minutes passed ---------
# 91
# 62
# 29
# 11
# 109
# 105
# 9
# 46
# 18
# 73
# 20
# 4
# 64
# 96
# 107
# 102
# 14
# 38
# 87
# 15
# ---------------------------------
# Similarity index       : 91
# Master Image file name : 89_0
# Nearest Neighbors.     : [91, 62, 29, 11, 109, 105, 9, 46, 18, 73, 20, 4, 64, 96, 107, 102, 14, 38, 87, 15]
# --- 0.81 minutes passed ---------
# 92
# 25
# 24
# 59
# 3
# 21
# 28
# 34
# 86
# 22
# 19
# 39
# 44
# 10
# 66
# 35
# 93
# 52
# 69
# 97
# ---------------------------------
# Similarity index       : 92
# Master Image file name : 87_0
# Nearest Neighbors.     : [92, 25, 24, 59, 3, 21, 28, 34, 86, 22, 19, 39, 44, 10, 66, 35, 93, 52, 69, 97]
# --- 0.81 minutes passed ---------
# 93
# 86
# 21
# 28
# 31
# 59
# 16
# 2
# 6
# 12
# 0
# 27
# 81
# 35
# 10
# 66
# 3
# 45
# 104
# 34
# ---------------------------------
# Similarity index       : 93
# Master Image file name : 81_0
# Nearest Neighbors.     : [93, 86, 21, 28, 31, 59, 16, 2, 6, 12, 0, 27, 81, 35, 10, 66, 3, 45, 104, 34]
# --- 0.81 minutes passed ---------
# 94
# 36
# 100
# 0
# 95
# 99
# 18
# 84
# 1
# 62
# 91
# 60
# 4
# 105
# 22
# 32
# 75
# 14
# 87
# 54
# ---------------------------------
# Similarity index       : 94
# Master Image file name : 88_0
# Nearest Neighbors.     : [94, 36, 100, 0, 95, 99, 18, 84, 1, 62, 91, 60, 4, 105, 22, 32, 75, 14, 87, 54]
# --- 0.81 minutes passed ---------
# 95
# 1
# 36
# 84
# 87
# 41
# 0
# 54
# 22
# 75
# 76
# 18
# 85
# 62
# 26
# 47
# 17
# 100
# 11
# 40
# ---------------------------------
# Similarity index       : 95
# Master Image file name : 90_0
# Nearest Neighbors.     : [95, 1, 36, 84, 87, 41, 0, 54, 22, 75, 76, 18, 85, 62, 26, 47, 17, 100, 11, 40]
# --- 0.81 minutes passed ---------
# 96
# 87
# 64
# 14
# 84
# 26
# 22
# 51
# 31
# 104
# 0
# 75
# 108
# 56
# 103
# 47
# 88
# 60
# 1
# 15
# ---------------------------------
# Similarity index       : 96
# Master Image file name : 8_0
# Nearest Neighbors.     : [96, 87, 64, 14, 84, 26, 22, 51, 31, 104, 0, 75, 108, 56, 103, 47, 88, 60, 1, 15]
# --- 0.81 minutes passed ---------
# 97
# 44
# 101
# 21
# 28
# 3
# 69
# 48
# 86
# 81
# 18
# 93
# 24
# 58
# 5
# 59
# 31
# 52
# 102
# 14
# ---------------------------------
# Similarity index       : 97
# Master Image file name : 84_0
# Nearest Neighbors.     : [97, 44, 101, 21, 28, 3, 69, 48, 86, 81, 18, 93, 24, 58, 5, 59, 31, 52, 102, 14]
# --- 0.81 minutes passed ---------
# 98
# 18
# 107
# 14
# 19
# 109
# 7
# 69
# 62
# 11
# 91
# 95
# 29
# 102
# 22
# 38
# 106
# 51
# 97
# 87
# ---------------------------------
# Similarity index       : 98
# Master Image file name : 91_0
# Nearest Neighbors.     : [98, 18, 107, 14, 19, 109, 7, 69, 62, 11, 91, 95, 29, 102, 22, 38, 106, 51, 97, 87]
# --- 0.81 minutes passed ---------
# 99
# 1
# 87
# 36
# 18
# 0
# 22
# 95
# 96
# 62
# 94
# 14
# 84
# 26
# 75
# 2
# 63
# 69
# 81
# 40
# ---------------------------------
# Similarity index       : 99
# Master Image file name : 83_0
# Nearest Neighbors.     : [99, 1, 87, 36, 18, 0, 22, 95, 96, 62, 94, 14, 84, 26, 75, 2, 63, 69, 81, 40]
# --- 0.81 minutes passed ---------
# 100
# 54
# 4
# 60
# 0
# 1
# 32
# 84
# 23
# 104
# 95
# 94
# 50
# 109
# 70
# 9
# 17
# 105
# 29
# 33
# ---------------------------------
# Similarity index       : 100
# Master Image file name : 80_0
# Nearest Neighbors.     : [100, 54, 4, 60, 0, 1, 32, 84, 23, 104, 95, 94, 50, 109, 70, 9, 17, 105, 29, 33]
# --- 0.81 minutes passed ---------
# 101
# 48
# 31
# 45
# 67
# 44
# 57
# 96
# 104
# 5
# 2
# 58
# 6
# 71
# 81
# 56
# 16
# 12
# 65
# 21
# ---------------------------------
# Similarity index       : 101
# Master Image file name : 76_0
# Nearest Neighbors.     : [101, 48, 31, 45, 67, 44, 57, 96, 104, 5, 2, 58, 6, 71, 81, 56, 16, 12, 65, 21]
# --- 0.81 minutes passed ---------
# 102
# 107
# 18
# 26
# 47
# 87
# 14
# 4
# 64
# 74
# 88
# 27
# 11
# 84
# 9
# 1
# 60
# 62
# 0
# 109
# ---------------------------------
# Similarity index       : 102
# Master Image file name : 74_0
# Nearest Neighbors.     : [102, 107, 18, 26, 47, 87, 14, 4, 64, 74, 88, 27, 11, 84, 9, 1, 60, 62, 0, 109]
# --- 0.81 minutes passed ---------
# 103
# 56
# 60
# 57
# 51
# 104
# 61
# 31
# 96
# 15
# 88
# 47
# 55
# 37
# 4
# 64
# 67
# 106
# 70
# 42
# ---------------------------------
# Similarity index       : 103
# Master Image file name : 73_3
# Nearest Neighbors.     : [103, 56, 60, 57, 51, 104, 61, 31, 96, 15, 88, 47, 55, 37, 4, 64, 67, 106, 70, 42]
# --- 0.81 minutes passed ---------
# 104
# 51
# 56
# 27
# 31
# 54
# 108
# 103
# 50
# 60
# 7
# 96
# 33
# 84
# 4
# 64
# 87
# 0
# 57
# 106
# ---------------------------------
# Similarity index       : 104
# Master Image file name : 73_2
# Nearest Neighbors.     : [104, 51, 56, 27, 31, 54, 108, 103, 50, 60, 7, 96, 33, 84, 4, 64, 87, 0, 57, 106]
# --- 0.81 minutes passed ---------
# 105
# 46
# 62
# 91
# 29
# 109
# 11
# 4
# 70
# 106
# 73
# 100
# 60
# 18
# 61
# 64
# 9
# 54
# 83
# 14
# ---------------------------------
# Similarity index       : 105
# Master Image file name : 77_0
# Nearest Neighbors.     : [105, 46, 62, 91, 29, 109, 11, 4, 70, 106, 73, 100, 60, 18, 61, 64, 9, 54, 83, 14]
# --- 0.81 minutes passed ---------
# 106
# 23
# 107
# 54
# 51
# 74
# 73
# 70
# 104
# 20
# 50
# 60
# 102
# 7
# 4
# 83
# 61
# 62
# 109
# 56
# ---------------------------------
# Similarity index       : 106
# Master Image file name : 76_1
# Nearest Neighbors.     : [106, 23, 107, 54, 51, 74, 73, 70, 104, 20, 50, 60, 102, 7, 4, 83, 61, 62, 109, 56]
# --- 0.81 minutes passed ---------
# 107
# 102
# 14
# 18
# 74
# 11
# 109
# 47
# 106
# 4
# 62
# 73
# 88
# 9
# 64
# 38
# 26
# 87
# 51
# 70
# ---------------------------------
# Similarity index       : 107
# Master Image file name : 79_0
# Nearest Neighbors.     : [107, 102, 14, 18, 74, 11, 109, 47, 106, 4, 62, 73, 88, 9, 64, 38, 26, 87, 51, 70]
# --- 0.81 minutes passed ---------
# 108
# 51
# 66
# 104
# 56
# 31
# 96
# 27
# 33
# 21
# 28
# 64
# 22
# 86
# 87
# 103
# 19
# 20
# 9
# 12
# ---------------------------------
# Similarity index       : 108
# Master Image file name : 7_0
# Nearest Neighbors.     : [108, 51, 66, 104, 56, 31, 96, 27, 33, 21, 28, 64, 22, 86, 87, 103, 19, 20, 9, 12]
# --- 0.81 minutes passed ---------
# 109
# 11
# 107
# 14
# 4
# 46
# 70
# 20
# 62
# 91
# 87
# 60
# 102
# 29
# 88
# 64
# 18
# 9
# 26
# 104
# ---------------------------------
# Similarity index       : 109
# Master Image file name : 75_0
# Nearest Neighbors.     : [109, 11, 107, 14, 4, 46, 70, 20, 62, 91, 87, 60, 102, 29, 88, 64, 18, 9, 26, 104]
# --- 0.81 minutes passed ---------
# Step.2 - Similarity score calculation - Finished
# Step.3 - Data stored in 'nearest_neighbors.json' file
# --- Prosess completed in 0.81 minutes ---------
# ---------------------------------
# Step.1 - ANNOY index generation - Started at Thu Jul  9 22:58:27 2020
# ---------------------------------
