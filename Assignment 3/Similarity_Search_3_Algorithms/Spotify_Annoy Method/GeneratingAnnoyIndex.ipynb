# %%
#################################################
# Imports and function definitions
#################################################
# For running inference on the TF-Hub module.
import tensorflow as tf
import tensorflow_hub as hub

# For saving 'feature vectors' into a txt file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# %%
#################################################
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

  return img

# %%
#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():

  i = 0

  start_time = time.time()

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at %s" %time.ctime())
  print("---------------------------------")

  # Definition of module with using tfhub.dev handle
  module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4" 
  
  # Load the module
  module = hub.load(module_handle)

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors -  Started at %s" %time.ctime())
 

  # Loops through all images in a local folder
  for filename in glob.glob('/content/drive/My Drive/110Images/*.jpg'): #assuming gif
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)   
  
    # Remove single-dimensional entries from the 'features' array
    feature_set = np.squeeze(features)  

    # Saves the image feature vectors into a file for later use

    outfile_name = os.path.basename(filename).split('.')[0] + ".npz"
    out_path = os.path.join('/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors', outfile_name)

    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

    print("Image feature vector saved to   :%s" %out_path)
  
  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors - Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
  print("--- %s images processed ---------" %i)
    
get_image_feature_vectors()
# Out:
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at Fri Jul 10 22:15:18 2020
# ---------------------------------
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at Fri Jul 10 22:15:20 2020
# --- 0.04 minutes passed ---------
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors -  Started at Fri Jul 10 22:15:20 2020
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :/content/drive/My Drive/110Images/31_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/31_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :/content/drive/My Drive/110Images/16_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/16_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :/content/drive/My Drive/110Images/88_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/88_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :/content/drive/My Drive/110Images/12_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/12_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :/content/drive/My Drive/110Images/8_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/8_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :/content/drive/My Drive/110Images/57_2.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/57_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :/content/drive/My Drive/110Images/101_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/101_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :/content/drive/My Drive/110Images/55_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/55_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :/content/drive/My Drive/110Images/36_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/36_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :/content/drive/My Drive/110Images/57_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/57_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :/content/drive/My Drive/110Images/73_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/73_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :/content/drive/My Drive/110Images/53_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors
0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/5_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :66
# Image in process is             :/content/drive/My Drive/110Images/52_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/52_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :67
# Image in process is             :/content/drive/My Drive/110Images/98_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/98_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :68
# Image in process is             :/content/drive/My Drive/110Images/33_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/33_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :69
# Image in process is             :/content/drive/My Drive/110Images/19_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/19_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :70
# Image in process is             :/content/drive/My Drive/110Images/98_3.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/98_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :71
# Image in process is             :/content/drive/My Drive/110Images/13_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/13_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :72
# Image in process is             :/content/drive/My Drive/110Images/83_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/83_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :73
# Image in process is             :/content/drive/My Drive/110Images/35_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/35_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :74
# Image in process is             :/content/drive/My Drive/110Images/81_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/81_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :75
# Image in process is             :/content/drive/My Drive/110Images/72_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/72_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :76
# Image in process is             :/content/drive/My Drive/110Images/98_2.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/98_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :77
# Image in process is             :/content/drive/My Drive/110Images/26_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/26_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :78
# Image in process is             :/content/drive/My Drive/110Images/3_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/3_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :79
# Image in process is             :/content/drive/My Drive/110Images/66_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/66_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :80
# Image in process is             :/content/drive/My Drive/110Images/19_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/19_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :81
# Image in process is             :/content/drive/My Drive/110Images/40_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/40_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :82
# Image in process is             :/content/drive/My Drive/110Images/84_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/84_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :83
# Image in process is             :/content/drive/My Drive/110Images/99_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/99_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :84
# Image in process is             :/content/drive/My Drive/110Images/80_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/80_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :85
# Image in process is             :/content/drive/My Drive/110Images/6_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/6_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :86
# Image in process is             :/content/drive/My Drive/110Images/4_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/4_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :87
# Image in process is             :/content/drive/My Drive/110Images/64_2.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/64_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :88
# Image in process is             :/content/drive/My Drive/110Images/42_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/42_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :89
# Image in process is             :/content/drive/My Drive/110Images/62_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/62_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :90
# Image in process is             :/content/drive/My Drive/110Images/62_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/62_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :91
# Image in process is             :/content/drive/My Drive/110Images/25_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/25_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :92
# Image in process is             :/content/drive/My Drive/110Images/18_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/18_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :93
# Image in process is             :/content/drive/My Drive/110Images/26_3.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/26_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :94
# Image in process is             :/content/drive/My Drive/110Images/79_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/79_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :95
# Image in process is             :/content/drive/My Drive/110Images/59_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/59_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :96
# Image in process is             :/content/drive/My Drive/110Images/60_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/60_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :97
# Image in process is             :/content/drive/My Drive/110Images/45_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/45_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :98
# Image in process is             :/content/drive/My Drive/110Images/61_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/61_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :99
# Image in process is             :/content/drive/My Drive/110Images/64_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/64_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :100
# Image in process is             :/content/drive/My Drive/110Images/44_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/44_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :101
# Image in process is             :/content/drive/My Drive/110Images/46_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/46_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :102
# Image in process is             :/content/drive/My Drive/110Images/25_2.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/25_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :103
# Image in process is             :/content/drive/My Drive/110Images/25_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/25_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :104
# Image in process is             :/content/drive/My Drive/110Images/25_3.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/25_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :105
# Image in process is             :/content/drive/My Drive/110Images/26_2.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/26_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :106
# Image in process is             :/content/drive/My Drive/110Images/42_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/42_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :107
# Image in process is             :/content/drive/My Drive/110Images/0_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/0_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :108
# Image in process is             :/content/drive/My Drive/110Images/2_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/2_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :109
# Image in process is             :/content/drive/My Drive/110Images/64_1.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/64_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :110
# Image in process is             :/content/drive/My Drive/110Images/38_0.jpg
# Image feature vector saved to   :/content/drive/My Drive/Algorithms and Digital Marketing/Assignment3/Vectors/38_0.npz
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors - Completed at Fri Jul 10 22:15:28 2020
# --- 0.18 minutes passed ---------
# --- 110 images processed ---------
