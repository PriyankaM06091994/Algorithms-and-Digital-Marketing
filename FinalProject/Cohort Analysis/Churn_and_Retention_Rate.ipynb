# %% [markdown]
# ***Churn and Retention Rate***

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/My Drive/cohort try/Amazon_Dataset.csv", decimal = '.')

# %%
df=df[(df['event_type']=='purchase')]

# %%
df.loc[pd.isnull(df.category_code),'category_code'] = 'Other.Other'
df['category_id_new'] = df['category_id']
df.loc[(df.category_code == 'Other.Other'),'category_id'] = 4444443555631882655
df.loc[pd.isnull(df.brand),'brand'] = 'Unknown'

# %%
import datetime
df['event_time'] = pd.to_datetime(df['event_time']).dt.date

# %%
df.head()
# Out:
#      event_time  ...      category_id_new
# 162  2019-10-01  ...  2053013555631882655
# 308  2019-10-01  ...  2053013555631882655
# 379  2019-10-01  ...  2053013553375346967
# 442  2019-10-01  ...  2053013557418656265
# 574  2019-10-01  ...  2053013554658804075
#
# [5 rows x 10 columns]

# %%
import pandas as pd
from time import strftime
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
 grouped = df.groupby('user_id')

# %%
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grouped_single= df.groupby('user_id').agg({'event_time':['min']})

# %%
grouped_single.columns = [ 'signup_date']

# %%
grouped_single = grouped_single.reset_index()

# %%
grouped_single.head(5)
# Out:
#      user_id signup_date
# 0  264649825  2019-10-06
# 1  303160429  2019-10-13
# 2  340041246  2019-10-03
# 3  371877401  2019-10-09
# 4  384989212  2019-10-18

# %%
grouped_single.shape
# Out:
# (347118, 2)

# %%
#merged_df= pd.concat([df, grouped_single], axis=1, join='left')
merged_df = pd.merge(left=df, right=grouped_single, left_on='user_id', right_on='user_id')

# %%
merged_df.head()
# Out:
#    event_time event_type  ...      category_id_new  signup_date
# 0  2019-10-01   purchase  ...  2053013555631882655   2019-10-01
# 1  2019-10-01   purchase  ...  2053013555631882655   2019-10-01
# 2  2019-10-02   purchase  ...  2053013555631882655   2019-10-01
# 3  2019-10-02   purchase  ...  2053013555531219353   2019-10-01
# 4  2019-10-02   purchase  ...  2053013555631882655   2019-10-01
#
# [5 rows x 11 columns]

# %%
df2['seniority'] = (df2['event_time'] - df2['signup_date']).dt.days + 1

df2.head(10)
# Out:
#    event_time event_type  ...  signup_date  seniority
# 0  2019-10-01   purchase  ...   2019-10-01          1
# 1  2019-10-01   purchase  ...   2019-10-01          1
# 2  2019-10-02   purchase  ...   2019-10-01          2
# 3  2019-10-02   purchase  ...   2019-10-01          2
# 4  2019-10-02   purchase  ...   2019-10-01          2
# 5  2019-10-03   purchase  ...   2019-10-01          3
# 6  2019-10-03   purchase  ...   2019-10-01          3
# 7  2019-10-04   purchase  ...   2019-10-01          4
# 8  2019-10-05   purchase  ...   2019-10-01          5
# 9  2019-10-06   purchase  ...   2019-10-01          6
#
# [10 rows x 12 columns]

# %%
group = df2.groupby(['signup_date', 'seniority'])

cohort_data = group['user_id'].size()

cohort_data = cohort_data.reset_index()

cohort_data
# Out:
#     signup_date  seniority  user_id
# 0    2019-10-01          1    19307
# 1    2019-10-01          2     2952
# 2    2019-10-01          3     2289
# 3    2019-10-01          4     2470
# 4    2019-10-01          5     1864
# ..          ...        ...      ...
# 491  2019-10-29          2      847
# 492  2019-10-29          3      471
# 493  2019-10-30          1    10456
# 494  2019-10-30          2      789
# 495  2019-10-31          1     9925
#
# [496 rows x 3 columns]

# %%
group.head()
# Out:
#         event_time event_type  ...  signup_date  seniority
# 0       2019-10-01   purchase  ...   2019-10-01          1
# 1       2019-10-01   purchase  ...   2019-10-01          1
# 2       2019-10-02   purchase  ...   2019-10-01          2
# 3       2019-10-02   purchase  ...   2019-10-01          2
# 4       2019-10-02   purchase  ...   2019-10-01          2
# ...            ...        ...  ...          ...        ...
# 732924  2019-10-31   purchase  ...   2019-10-31          1
# 732925  2019-10-31   purchase  ...   2019-10-31          1
# 732926  2019-10-31   purchase  ...   2019-10-31          1
# 732927  2019-10-31   purchase  ...   2019-10-31          1
# 732928  2019-10-31   purchase  ...   2019-10-31          1
#
# [2480 rows x 12 columns]

# %%
type(cohort_data)
# Out:
# pandas.core.frame.DataFrame

# %%
cohort_data=cohort_data.rename(columns={'Seniority': 'seniority'})

# %%
cohort_data.head(5)
# Out:
#   signup_date  seniority  user_id
# 0  2019-10-01          1    19307
# 1  2019-10-01          2     2952
# 2  2019-10-01          3     2289
# 3  2019-10-01          4     2470
# 4  2019-10-01          5     1864

# %%
cohort_counts = cohort_data.pivot(index='signup_date', columns='seniority', values='user_id')
base = cohort_counts[1]

# We apply the divide method to our cohort_counts, dividing it by the base
retention = cohort_counts.divide(base, axis=0).round(3)

# %%
cohort_counts
# Out:
# seniority         1       2       3       4   ...     28     29     30     31
# signup_date                                   ...
# 2019-10-01   19307.0  2952.0  2289.0  2470.0  ...  917.0  871.0  854.0  903.0
# 2019-10-02   16517.0  1787.0  1832.0  1324.0  ...  595.0  552.0  531.0    NaN
# 2019-10-03   15179.0  1939.0  1169.0   970.0  ...  454.0  470.0    NaN    NaN
# 2019-10-04   20800.0  1990.0  1268.0  1174.0  ...  430.0    NaN    NaN    NaN
# 2019-10-05   17147.0  1405.0   915.0   829.0  ...    NaN    NaN    NaN    NaN
# 2019-10-06   15801.0  1366.0   817.0   745.0  ...    NaN    NaN    NaN    NaN
# 2019-10-07   14186.0  1382.0   923.0   747.0  ...    NaN    NaN    NaN    NaN
# 2019-10-08   15204.0  1298.0   806.0   799.0  ...    NaN    NaN    NaN    NaN
# 2019-10-09   14650.0  1222.0   882.0   743.0  ...    NaN    NaN    NaN    NaN
# 2019-10-10   13794.0  1238.0   767.0   707.0  ...    NaN    NaN    NaN    NaN
# 2019-10-11   16765.0  1335.0   897.0   874.0  ...    NaN    NaN    NaN    NaN
# 2019-10-12   16249.0  1309.0   866.0   684.0  ...    NaN    NaN    NaN    NaN
# 2019-10-13   19210.0  1464.0   813.0   766.0  ...    NaN    NaN    NaN    NaN
# 2019-10-14   15952.0  1420.0  1038.0   836.0  ...    NaN    NaN    NaN    NaN
# 2019-10-15   14519.0  1394.0   799.0   644.0  ...    NaN    NaN    NaN    NaN
# 2019-10-16   18130.0  1528.0   954.0   628.0  ...    NaN    NaN    NaN    NaN
# 2019-10-17   15247.0  1193.0   719.0   545.0  ...    NaN    NaN    NaN    NaN
# 2019-10-18   13907.0   977.0   653.0   586.0  ...    NaN    NaN    NaN    NaN
# 2019-10-19   13858.0   989.0   596.0   511.0  ...    NaN    NaN    NaN    NaN
# 2019-10-20   14239.0   908.0   561.0   508.0  ...    NaN    NaN    NaN    NaN
# 2019-10-21   13543.0  1126.0   596.0   485.0  ...    NaN    NaN    NaN    NaN
# 2019-10-22   13581.0  1048.0   585.0   466.0  ...    NaN    NaN    NaN    NaN
# 2019-10-23   13129.0   986.0   529.0   387.0  ...    NaN    NaN    NaN    NaN
# 2019-10-24   12592.0   932.0   448.0   420.0  ...    NaN    NaN    NaN    NaN
# 2019-10-25   12414.0   882.0   487.0   375.0  ...    NaN    NaN    NaN    NaN
# 2019-10-26   12072.0   855.0   478.0   341.0  ...    NaN    NaN    NaN    NaN
# 2019-10-27   12400.0   849.0   451.0   362.0  ...    NaN    NaN    NaN    NaN
# 2019-10-28   10588.0   727.0   433.0   308.0  ...    NaN    NaN    NaN    NaN
# 2019-10-29   10269.0   847.0   471.0     NaN  ...    NaN    NaN    NaN    NaN
# 2019-10-30   10456.0   789.0     NaN     NaN  ...    NaN    NaN    NaN    NaN
# 2019-10-31    9925.0     NaN     NaN     NaN  ...    NaN    NaN    NaN    NaN
#
# [31 rows x 31 columns]

# %%
retention = cohort_counts.divide(base,axis=0).round(3)
retention
# Out:
# seniority     1      2      3      4      5   ...     27     28     29     30     31
# signup_date                                   ...
# 2019-10-01   1.0  0.153  0.119  0.128  0.097  ...  0.047  0.047  0.045  0.044  0.047
# 2019-10-02   1.0  0.108  0.111  0.080  0.065  ...  0.034  0.036  0.033  0.032    NaN
# 2019-10-03   1.0  0.128  0.077  0.064  0.063  ...  0.030  0.030  0.031    NaN    NaN
# 2019-10-04   1.0  0.096  0.061  0.056  0.054  ...  0.025  0.021    NaN    NaN    NaN
# 2019-10-05   1.0  0.082  0.053  0.048  0.044  ...  0.018    NaN    NaN    NaN    NaN
# 2019-10-06   1.0  0.086  0.052  0.047  0.044  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-07   1.0  0.097  0.065  0.053  0.047  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-08   1.0  0.085  0.053  0.053  0.042  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-09   1.0  0.083  0.060  0.051  0.047  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-10   1.0  0.090  0.056  0.051  0.056  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-11   1.0  0.080  0.054  0.052  0.041  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-12   1.0  0.081  0.053  0.042  0.039  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-13   1.0  0.076  0.042  0.040  0.040  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-14   1.0  0.089  0.065  0.052  0.050  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-15   1.0  0.096  0.055  0.044  0.037  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-16   1.0  0.084  0.053  0.035  0.030  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-17   1.0  0.078  0.047  0.036  0.038  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-18   1.0  0.070  0.047  0.042  0.036  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-19   1.0  0.071  0.043  0.037  0.033  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-20   1.0  0.064  0.039  0.036  0.030  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-21   1.0  0.083  0.044  0.036  0.031  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-22   1.0  0.077  0.043  0.034  0.029  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-23   1.0  0.075  0.040  0.029  0.029  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-24   1.0  0.074  0.036  0.033  0.032  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-25   1.0  0.071  0.039  0.030  0.031  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-26   1.0  0.071  0.040  0.028  0.024  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-27   1.0  0.068  0.036  0.029  0.027  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-28   1.0  0.069  0.041  0.029    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-29   1.0  0.082  0.046    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-30   1.0  0.075    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 2019-10-31   1.0    NaN    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
#
# [31 rows x 31 columns]

# %%
# User Count heatmap
plt.figure(figsize=(20,20))
plt.title('Users Active')
ax = sns.heatmap(data=cohort_counts/1000, annot=True, vmin=0.0,cmap='Blues')
ax.set_yticklabels(cohort_counts.index)
fig=ax.get_figure()
fig.savefig("Retention Counts.png")

plt.show()

# %%
# Retention Rate heatmap
plt.figure(figsize=(18,14))
plt.title('Retention Table')
ax = sns.heatmap(data=retention, annot=True, fmt='.0%', vmin=0.0, vmax=1,cmap='Blues')
ax.set_yticklabels(retention.index)
fig=ax.get_figure()
fig.savefig("Retention_Rate.png")

plt.show()
