# %% [markdown]
# #### Merging two CSV's in Pandas

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("/Users/Priyanka Malpekar/Desktop/Dataset/Amazon_Products_A.csv")

# %%
df_1.head(1)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
#
#                                                 keys  ...  \
# 0  allnewkindleereaderblack6glarefreetouchscreend...  ...
#
#                                     reviews.dateSeen reviews.doRecommend  \
# 0  2018-05-27T00:00:00Z,2017-09-18T00:00:00Z,2017...               False
#
#   reviews.id reviews.numHelpful reviews.rating  \
# 0        NaN                  0              3
#
# ...

# %%
df_1.count()
# Out:
# id                     5000
# dateAdded              5000
# dateUpdated            5000
# name                   5000
# asins                  5000
# brand                  5000
# categories             5000
# primaryCategories      5000
# imageURLs              5000
# keys                   5000
# manufacturer           5000
# manufacturerNumber     5000
# reviews.date           5000
# reviews.dateAdded      1052
# reviews.dateSeen       5000
# reviews.doRecommend    5000
# reviews.id               29
# reviews.numHelpful     5000
# reviews.rating         5000
# reviews.sourceURLs     5000
# reviews.text           5000
# reviews.title          4987
# reviews.username       5000
# sourceURLs             5000
# dtype: int64

# %%
df_2 = pd.read_csv("/Users/Priyanka Malpekar/Desktop/Dataset/Amazon_Products_B.csv")

# %%
df_2.head(1)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
#
#                                   reviews.sourceURLs  \
# ...

# %%
df_2.count()
# Out:
# id                     28332
# dateAdded              28332
# dateUpdated            28332
# name                   28332
# asins                  28332
# brand                  28332
# categories             28332
# primaryCategories      28332
# imageURLs              28332
# keys                   28332
# manufacturer           28332
# manufacturerNumber     28332
# reviews.date           28332
# reviews.dateSeen       28332
# reviews.didPurchase        9
# reviews.doRecommend    16086
# reviews.id                41
# reviews.numHelpful     16115
# reviews.rating         28332
# reviews.sourceURLs     28332
# reviews.text           28332
# reviews.title          28332
# reviews.username       28332
# sourceURLs             28332
# dtype: int64

# %%
df_Final = pd.concat([df_1,df_2])
# Out:
# C:\Users\Priyanka Malpekar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_Final
# Out:
#             asins   brand                                         categories  \
# 0      B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 1      B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 2      B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 3      B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# 4      B00ZV9PXP2  Amazon  Computers,Electronics Features,Tablets,Electro...
# ...           ...     ...                                                ...
# 28327  B018T075DC  Amazon  Fire Tablets,Tablets,All Tablets,Amazon Tablet...
# 28328  B018T075DC  Amazon  Fire Tablets,Tablets,All Tablets,Amazon Tablet...
# 28329  B018T075DC  Amazon  Fire Tablets,Tablets,All Tablets,Amazon Tablet...
# 28330  B018T075DC  Amazon  Fire Tablets,Tablets,All Tablets,Amazon Tablet...
# 28331  B018T075DC  Amazon  Fire Tablets,Tablets,All Tablets,Amazon Tablet...
#
# ...

# %%
try:
    import elasticsearch
    from elasticsearch import Elasticsearch
    
    import pandas as pd
    import json
    from ast import literal_eval
    from tqdm import tqdm
    import datetime
    import os
    import sys
    
    import os
    import tensorflow as tf
    import tensorflow_hub as hub
    import numpy as np
    
    from elasticsearch import helpers
    print("Loaded  .. . . . . . . .")
except Exception as E:
    print("Some Modules are Missing {} ".format(e))

# %%
# Load the ML Model 
embed = hub.KerasLayer(os.getcwd())

# %%
def apply_transform(x):
    
    tem = str(x)
    x = tf.constant([tem])
    embeddings = embed(x)
    print(embeddings)
    x = np.asarray(embeddings)
    print(x)
    x = x[0].tolist()
    return x
